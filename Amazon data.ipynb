# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("D:\sonia\skill lync\Amazon Sales data.csv")

# %%
dataset
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
dataset.head(2)
# Out:
#                               Region  Country  Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H  5/28/2010  669165933  6/27/2010        9925      255.28
# 1              C  8/22/2012  963881480  9/15/2012        2804      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit Order Date2  Ship Date2
# 0     159.42      2533654.0  1582243.50     951410.50  28-05-2010  27-06-2010
# 1     117.11       576782.8   328376.44     248406.36  22-08-2012  15-09-2012

# %%
dataset.shape
# Out:
# (100, 16)

# %%
dataset.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# Order Date2       0
# Ship Date2        0
# dtype: int64

# %%
dataset['Item Type'].value_counts()
# Out:
# Item Type
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Baby Food           7
# Cereal              7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: count, dtype: int64

# %%
dataset['Sales Channel'].value_counts()
# Out:
# Sales Channel
# Offline    50
# Online     50
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['H', 'C', 'L', 'M'], dtype=object)

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# H    30
# L    27
# C    22
# M    21
# Name: count, dtype: int64

# %%
#EDA

# %%
# FROM THE BELOW CHART WE CAN SEE THAT MOST OF ORDER PRIORITY 
plt.figure(figsize=(4,4))
sns.countplot(x="Order Priority",data =dataset)
plt.title("Count of Order Priority")
plt.savefig("count of Order Priority.jpg")
plt.show()

# %%
#FROM THE  ELOW CHART WE CAN SEE THAT HOW MUCH ITEM TYPE CONTRIBUTE TO REVENUE GENERATE
plt.figure(figsize=(20,6))
sns.countplot(x="Item Type",data =dataset)
plt.title("count of Item Type")
plt.savefig("count of Item Type.jpg")
plt.show()

# %%
dataset.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
dataset['Country'].value_counts()
# Out:
# Country
# The Gambia               4
# Sierra Leone             3
# Sao Tome and Principe    3
# Mexico                   3
# Australia                3
#                         ..
# Comoros                  1
# Iceland                  1
# Macedonia                1
# Mauritania               1
# Mozambique               1
# Name: count, Length: 76, dtype: int64

# %%
# FROM THE BELOW CHART WE CAN ABOARSED ABOUT THE TOTAL PROFIT BY BOXPLOT 
sns.boxplot(dataset['Total Profit'])
# Out:
# <Axes: >

# %%
# FROM THE BELOW CHART WE CAN SEE THAT H CONTRIBUTE MORE OFFLINE BUT L CONTRI MORE IN ONLINE
plt.figure(figsize=(5,4))
sns.countplot(x='Order Priority',data= dataset,hue="Sales Channel")
plt.show()

# %%
#  REGION SUB SHARANN AFRICA IS THE HIGHEST REGION BY OFFLINE
plt.figure(figsize=(20,20))
sns.countplot(x='Region',data= dataset,hue="Sales Channel")
plt.title("Count of Region By Sales Channel")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot(x="Order Priority",data= dataset[dataset["Order Priority"]=="L"],hue="Item Type")
plt.title("Count of Order priority  by L on the bases of Item Type")
plt.show()

# WE CAN SEE THE HOUSEHOLD AND FRUITS SOLD MOST FROM OTHER BY L ORDER PRIORITY

# %%
plt.figure(figsize=(12,10))
sns.countplot(x="Order Priority",data= dataset[dataset["Order Priority"]=="M"],hue="Item Type")
plt.title("Count of Order priority  by M on the bases of Item Type")
plt.show()


# WE CAN SEE THE OFFICE SUPPLIES SOLD MOST FROM OTHER BY' M 'ORDER PRIORITY

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
#  14  Order Date2     100 non-null    object
#  15  Ship Date2      100 non-null    object
# dtypes: float64(5), int64(2), object(9)
# ...

# %%
dataset['Order Date2'].value_counts()
# Out:
# Order Date2
# 28-05-2010    1
# 30-10-2010    1
# 20-05-2017    1
# 26-05-2011    1
# 14-08-2015    1
#              ..
# 17-09-2012    1
# 26-05-2012    1
# 18-07-2014    1
# 07-05-2010    1
# 10-02-2012    1
# Name: count, Length: 100, dtype: int64

# %%
#  WE CAN OBSERVED THE TOTAL REVENUE BY DISPLOT 

sns.distplot(dataset['Total Revenue'])
# Out:
# C:\Users\ritud\AppData\Local\Temp\ipykernel_13088\3358967717.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Total Revenue'])
# <Axes: xlabel='Total Revenue', ylabel='Density'>

# %%
# WE AN OBSERVED THE TOTAL PROFIT BY DISPLOT
sns.distplot(dataset['Total Profit'])
# Out:
# C:\Users\ritud\AppData\Local\Temp\ipykernel_13088\4054901756.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Total Profit'])
# <Axes: xlabel='Total Profit', ylabel='Density'>

# %%
# FROM THIE BAR PLOT WE CAN OBSERVED THE TOTAL PROFIT BY ORDER PRIORITY , "H" CONTRIBUTE HIGH PROFIT
sns.barplot(x="Order Priority",y="Total Profit",data=dataset,estimator="sum")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(22,10))
sns.barplot(x="Item Type",y="Total Profit",data=dataset,estimator="sum")
plt.show

# FROM THE BELOW CHART WE CAN OBSERVED THAT BY THE SOLD OF FRUITS ITEM GENERATE LESS PROFIT , AND COSMETIC PRODUCT SOLD WITH HIGH PROFIT
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# OVERALL TOTAL PROFITS BY OFFLINE SELLING
plt.figure(figsize=(5,4))
sns.barplot(x="Sales Channel",y="Total Profit",data=dataset,estimator="mean")
# Out:
# <Axes: xlabel='Sales Channel', ylabel='Total Profit'>

# %%
plt.figure(figsize=(20,6))
sns.barplot(x="Region",y="Total Profit",data=dataset,estimator="sum")

# TOTAL REVENUE BY REGION
# NORTH AMERICA GENERATE LESS PROFIT  AS COMPARE WITH OTHER
# Out:
# <Axes: xlabel='Region', ylabel='Total Profit'>

# %%
#Total 5 selling Region 
dataset['Region'].value_counts()[:5]
# Out:
# Region
# Sub-Saharan Africa              36
# Europe                          22
# Australia and Oceania           11
# Asia                            11
# Middle East and North Africa    10
# Name: count, dtype: int64

# %%
# top 5 selling country
dataset['Country'].value_counts()[:5]
# Out:
# Country
# The Gambia               4
# Sierra Leone             3
# Sao Tome and Principe    3
# Mexico                   3
# Australia                3
# Name: count, dtype: int64

# %%
# Top 5 most sold Item type

dataset['Item Type'].value_counts()[:5]
# Out:
# Item Type
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Name: count, dtype: int64

# %%
dataset.head(1)
# Out:
#                   Region Country  Item Type Sales Channel Order Priority  \
# 0  Australia and Oceania  Tuvalu  Baby Food       Offline              H
#
#   Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0  5/28/2010  669165933  6/27/2010        9925      255.28     159.42
#
#    Total Revenue  Total Cost  Total Profit Order Date2  Ship Date2
# 0      2533654.0   1582243.5      951410.5  28-05-2010  27-06-2010

# %%
#Top 10 most revenue earned by region
fig1,ax1=plt.subplots(figsize=(12,7))
dataset.groupby('Region')['Total Revenue'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
#Top 10 most revenue earned by country
fig1,ax1=plt.subplots(figsize=(12,7))
dataset.groupby('Country')['Total Revenue'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
#over all conclusion  we have to increase our sales in North America, less total profit margin  is from fruit , 
#we have increase and top most profit margin is from cosmetic and from household
# we observe that order priority by M  is the office suppler is higher than other
# In sub saharan africa region offile sale is greater than online
# Order prioinerity by H offline is greater than online
# the honduras country generate maximum revenue 
# the sub saharan africa generate maximum revenue and total profit 
# the gambia is the top selling country
